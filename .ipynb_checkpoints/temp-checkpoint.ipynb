# %%
import os
import glob
import random
import pandas as pd
from trdg.generators import GeneratorFromStrings

output_dir = "corpus_dataset_1"
os.makedirs(output_dir, exist_ok=True)

df = pd.read_csv("corpus_1.tsv", sep="\t", header=0, names=["id", "lang", "text"], on_bad_lines="skip", skiprows=1)

all_fonts = glob.glob("hw_fonts/*.ttf") + glob.glob("hw_fonts/*.otf")

# sesi!!!!
start = 0
end = 1

for _, row in df.iloc[start:end].iterrows():
    for i in range(50):
        gen = GeneratorFromStrings(
            [row["text"]],
            fonts=[random.choice(all_fonts)],
            skewing_angle=random.randint(0, 8),
            random_skew=True,
            distorsion_type=random.randint(0, 3),
            distorsion_orientation=random.randint(0, 2),
            background_type=random.randint(0, 1),
            size=random.randint(48, 96),
            fit=True,
        )
        for img, _ in gen:
            img.save(os.path.join(output_dir, f"{row['id']}_{i}.png"))

print(f"Done! Sesi {start}-{end} selesai.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\Miniconda3\envs\ocr\lib\site-packages\PIL\ImageFile.py:515, in _save(im, fp, tile, bufsize)
#     514 try:
# --> 515     fh = fp.fileno()
#     516     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 32
#      20         gen = GeneratorFromStrings(
#      21             [row["text"]],
#      22             fonts=[random.choice(all_fonts)],
#    (...)
#      29             fit=True,
#      30         )
#      31         for img, _ in gen:
# ---> 32             img.save(os.path.join(output_dir, f"{row['id']}_{i}.png"))
#      34 print(f"Done! Sesi {start}-{end} selesai.")
#
# File D:\Miniconda3\envs\ocr\lib\site-packages\PIL\Image.py:2432, in Image.save(self, fp, format, **params)
#    2429         fp = builtins.open(filename, "w+b")
#    2431 try:
# -> 2432     save_handler(self, fp, filename)
#    2433 except Exception:
#    2434     if open_fp:
#
# File D:\Miniconda3\envs\ocr\lib\site-packages\PIL\PngImagePlugin.py:1407, in _save(im, fp, filename, chunk, save_all)
#    1405     _write_multiple_frames(im, fp, chunk, rawmode, default_image, append_images)
#    1406 else:
# -> 1407     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1409 if info:
#    1410     for info_chunk in info.chunks:
#
# File D:\Miniconda3\envs\ocr\lib\site-packages\PIL\ImageFile.py:519, in _save(im, fp, tile, bufsize)
#     517     _encode_tile(im, fp, tile, bufsize, fh)
#     518 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 519     _encode_tile(im, fp, tile, bufsize, None, exc)
#     520 if hasattr(fp, "flush"):
#     521     fp.flush()
#
# File D:\Miniconda3\envs\ocr\lib\site-packages\PIL\ImageFile.py:538, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     535 if exc:
#     536     # compress to Python file-compatible object
#     537     while True:
# --> 538         errcode, data = encoder.encode(bufsize)[1:]
#     539         fp.write(data)
#     540         if errcode:
#
# KeyboardInterrupt:

# %%
import os
files = os.listdir("corpus_dataset_1")
print(f"Total file: {len(files)}")
print(files[:10])
# Out:
# Total file: 2
# ['331311_0.png', 'id_0.png']

# %%
import os
import glob
import random
import pandas as pd
from trdg.generators import GeneratorFromStrings

output_dir = "corpus_dataset_1"
os.makedirs(output_dir, exist_ok=True)

df = pd.read_csv("corpus_1.tsv", sep="\t", header=None, names=["id", "lang", "text"], on_bad_lines="skip")
df = df[df["id"] != "id"].reset_index(drop=True)  # buang baris header kalau masih ada

all_fonts = glob.glob("hw_fonts/*.ttf") + glob.glob("hw_fonts/*.otf")

start = 0
end = 1

for _, row in df.iloc[start:end].iterrows():
    for i in range(50):
        gen = GeneratorFromStrings(
            [row["text"]],
            fonts=[random.choice(all_fonts)],
            skewing_angle=random.randint(0, 8),
            random_skew=True,
            distorsion_type=random.randint(0, 3),
            distorsion_orientation=random.randint(0, 2),
            background_type=random.randint(0, 1),
            size=random.randint(48, 96),
            fit=True,
        )
        img, _ = next(iter(gen))  # ambil 1 gambar saja, tidak loop
        img.save(os.path.join(output_dir, f"{row['id']}_{i}.png"))

print(f"Done! Sesi {start}-{end} selesai.")
# Out:
# Done! Sesi 0-1 selesai.
